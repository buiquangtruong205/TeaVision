# %% [markdown]
# # 01 - EDA & Cleaning
#
# Notebook này kiểm tra chất lượng ảnh đã được chia theo thư mục bệnh, phát hiện ảnh hỏng/ảnh nhỏ/ảnh trùng, tạo báo cáo EDA và metadata sạch để dùng cho các bước split/train.

# %%
from pathlib import Path
import pandas as pd
from IPython.display import Image, display, Markdown

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
DATASET_DIR = PROJECT_ROOT / 'dataset'
SPLITS_DIR = PROJECT_ROOT / 'data' / 'splits'
REPORTS_DIR = PROJECT_ROOT / 'reports'
FIGURES_DIR = REPORTS_DIR / 'figures'

print(PROJECT_ROOT)
print(DATASET_DIR)
# Out:
# /content
# /content/dataset

# %% [markdown]
# ## Run EDA Pipeline
#
# Script dưới đây sẽ:
#
# - đếm ảnh mỗi lớp,
# - phát hiện ảnh hỏng,
# - phát hiện ảnh nhỏ hơn `32x32`,
# - phát hiện ảnh trùng bằng `imagehash.phash`,
# - tạo metadata sạch,
# - xuất biểu đồ và báo cáo EDA.

# %%
# !python ../scripts/run_eda_cleaning.py --dataset-dir ../dataset --splits-dir ../data/splits --reports-dir ../reports --config-dir ../config --min-size 32
# Out:
# python3: can't open file '/content/../scripts/run_eda_cleaning.py': [Errno 2] No such file or directory

# %% [markdown]
# ## Summary

# %%
summary = pd.read_json(SPLITS_DIR / 'eda_summary.json', typ='series')
summary
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_2494/2213194702.py in <cell line: 0>()
# ----> 1 summary = pd.read_json(SPLITS_DIR / 'eda_summary.json', typ='series')
#       2 summary
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/json/_json.py in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, precise_float, date_unit, encoding, encoding_errors, lines, chunksize, compression, nrows, storage_options, dtype_backend, engine)
#     789         convert_axes = True
#     790
# --> 791     json_reader = JsonReader(
#     792         path_or_buf,
#     793         orient=orient,
#
# ...

# %% [markdown]
# ## Class Distribution

# %%
display(Image(filename=str(FIGURES_DIR / 'class_distribution.png')))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_2494/843656173.py in <cell line: 0>()
# ----> 1 display(Image(filename=str(FIGURES_DIR / 'class_distribution.png')))
#
# /usr/local/lib/python3.12/dist-packages/IPython/core/display.py in __init__(self, data, url, filename, format, embed, width, height, retina, unconfined, metadata)
#    1229         self.retina = retina
#    1230         self.unconfined = unconfined
# -> 1231         super(Image, self).__init__(data=data, url=url, filename=filename,
#    1232                 metadata=metadata)
#    1233
#
# /usr/local/lib/python3.12/dist-packages/IPython/core/display.py in __init__(self, data, url, filename, metadata)
#     635             self.metadata = {}
#     636
# --> 637         self.reload()
#     638         self._check_data()
#     639
#
# ...

# %% [markdown]
# ## Sample Images

# %%
display(Image(filename=str(FIGURES_DIR / 'sample_images.png')))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_2494/3130072334.py in <cell line: 0>()
# ----> 1 display(Image(filename=str(FIGURES_DIR / 'sample_images.png')))
#
# /usr/local/lib/python3.12/dist-packages/IPython/core/display.py in __init__(self, data, url, filename, format, embed, width, height, retina, unconfined, metadata)
#    1229         self.retina = retina
#    1230         self.unconfined = unconfined
# -> 1231         super(Image, self).__init__(data=data, url=url, filename=filename,
#    1232                 metadata=metadata)
#    1233
#
# /usr/local/lib/python3.12/dist-packages/IPython/core/display.py in __init__(self, data, url, filename, metadata)
#     635             self.metadata = {}
#     636
# --> 637         self.reload()
#     638         self._check_data()
#     639
#
# ...

# %% [markdown]
# ## Cleaning Outputs

# %%
files = [
    'eda_metadata.csv',
    'cleaned_metadata.csv',
    'corrupted_images.csv',
    'small_images.csv',
    'exact_duplicates.csv',
    'phash_duplicates.csv',
]
for name in files:
    path = SPLITS_DIR / name
    df = pd.read_csv(path)
    print(f'{name}: {len(df)} rows')

# %%
duplicates = pd.read_csv(SPLITS_DIR / 'phash_duplicates.csv')
duplicates.head(20)

# %% [markdown]
# ## EDA Report

# %%
display(Markdown((REPORTS_DIR / 'eda_report.md').read_text(encoding='utf-8')))
